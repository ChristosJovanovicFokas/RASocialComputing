# %%
import pandas as pd

file_path = "../data/domains_annotated.csv"
df = pd.read_csv(file_path)
df.head(5)
# Out:
#                       column A  count           category  \
# 0     manifestationmatters.com    180  standalone_domain
# 1            nextlevelsoul.com    151  standalone_domain
# 2             elliotoracle.com     89  standalone_domain
# 3  dailydevotionalinchrist.com     64              other
# 4          icandosomething.com     39              other
#
#                                 Product Listing Page  \
# 0  https://manifestationmatters.com/manifestation...
# 1  https://watch.nextlevelsoul.com/category/event...
# 2                     https://elliotoracle.com/shop/
# 3                                                NaN
# 4                                                NaN
#
#                                           About Page  \
# 0  https://manifestationmatters.com/category/law-...
# 1                    https://nextlevelsoul.com/blog/
# 2                          https://elliotoracle.com/
# 3                                                NaN
# ...

# %%
from bs4 import BeautifulSoup
url = df["Product Listing Page"].iloc[0]
print(url)
# Out:
# https://manifestationmatters.com/manifestation-matters-store/
